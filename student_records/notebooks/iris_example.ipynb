# %%
from pml.api import *

# %%
data = load("iris.csv")

# %%
data.num_samples()
# Out:
# 150

# %%
data.feature_list()
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
data.plot_radviz()
